# %%
# !pip install ultralytics
# !pip install wandb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.0/705.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 25.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 29.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
import random
import shutil
import numpy as np
import pandas as pd
import cv2
import yaml
import matplotlib.pyplot as plt
import glob
from sklearn.model_selection import train_test_split
from IPython.display import Image

# %%
# %%writefile /content/drive/MyDrive/Photo/dataset.yaml
# # Path
# path: /content/drive/MyDrive/Photo
# train: images/train
# val: images/valid
#
# # Classes
# nc: 5
# names: ['signboard', 'advertise', 'rider', 'car', 'bus']
# Out:
# Overwriting /content/drive/MyDrive/Photo/dataset.yaml

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml') # build a new model from YAML
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
model = YOLO('yolov8n.yaml').load('yolov8n.pt') # build from YAML and transfer weights

# Train the model
results = model.train(data='/content/drive/MyDrive/Photo/dataset.yaml', epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 78.9MB/s]
# Transferred 355/355 items from pretrained weights
# Ultralytics YOLOv8.1.6 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('./runs/detect/train/weights/best.pt')
ret = model("/content/drive/MyDrive/Photo/testing_image",save=True, conf=0.2, iou=0.5)
# Out:
# image 1/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 38 59.jpeg: 352x640 3 signboards, 2 cars, 174.4ms
# image 2/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 42 48.jpeg: 416x640 4 signboards, 2 cars, 65.9ms
# image 3/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 43 25.jpeg: 416x640 7 signboards, 8 cars, 9.8ms
# image 4/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 44 29.jpeg: 416x640 6 signboards, 1 advertise, 4 cars, 9.1ms
# image 5/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 45 02.jpeg: 416x640 7 signboards, 7 cars, 8.6ms
# image 6/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 45 46.jpeg: 416x640 6 signboards, 5 cars, 9.5ms
# image 7/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 46 09.jpeg: 416x640 7 signboards, 3 riders, 5 cars, 11.1ms
# image 8/14 /content/drive/MyDrive/Photo/testing_image/2024-01-26 14 47 01.jpeg: 416x640 2 signboards, 6 cars, 19.1ms
# ...

# %%
# display result
files = glob.glob("./runs/detect/predict/*")
for i in range(0,15):
    img = Image(files[i])
    display(img)
